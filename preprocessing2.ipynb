# %%
import numpy as np
import pandas as pd

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4, ignore_index=True), ignore_index=True), ignore_index=True)
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
from tmdbv3api import TMDb
import json 
import requests
tmdb=TMDb()
tmdb.api_key='0c7d49bc5b86d2ee888748372078b1cb'

# %%
from tmdbv3api import Movie
tmdb_movie=Movie()

def g_genre(x):
    gen=[]
    result=tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = ' '
        for i in range(0, len(data_json['genres'])):
            gen.append(data_json['genres'][i]['name'])
        return genre_str.join(gen)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: g_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018['Cast and crew'][1]
# Out:
# 'Lauren Wolkstein (director); Christopher Radcliff (co-director/screenplay); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell'

# %%
def g_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screeplay)")[0]
    
def g_actor1(x):
    return ((x.split('screenplay); ')[-1].split(', '))[0])

def g_actor2(x):
    if len(x.split('screenplay); ')[-1].split(', ')) < 2:
        return np.NaN
    else:
        return ((x.split('screenplay); ')[-1].split(', '))[1])

def g_actor3(x):
    if len(x.split('screenplay); ')[-1].split(', ')) < 3:
        return np.NaN
    else:
        return ((x.split('screenplay); ')[-1].split(', '))[2])

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: g_director(x))
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: g_actor1(x))
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: g_actor2(x))
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: g_actor3(x))
# Out:
# <ipython-input-12-4326f6eba708>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: g_director(x))
# <ipython-input-12-4326f6eba708>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: g_actor1(x))
# <ipython-input-12-4326f6eba708>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018=df_2018.rename(columns={'Title':'movie_title'})

# %%
df_2018
# Out:
#                     movie_title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
new_df18 = df_2018.loc[:,['director_name', 'actor_1_name','actor_2_name', 'actor_3_name', 'genres', 'movie_title']]

# %%
new_df18
# Out:
#                                          director_name     actor_1_name  \
# 0                                         Adam Robitel        Lin Shaye
# 1                                     Lauren Wolkstein    Alex Pettyfer
# 2                                           Simon West   Dominic Cooper
# 3                                     Warwick Thornton      Bryan Brown
# 4                                   Jaume Collet-Serra      Liam Neeson
# ..                                                 ...              ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...     Will Ferrell
# 263  Adam McKay (director/screenplay); Christian Ba...   Christian Bale
# 264                                         Mimi Leder   Felicity Jones
# 265                                       Karyn Kusama    Nicole Kidman
# 266                                        David Slade  Fionn Whitehead
#
#                actor_2_name    actor_3_name  \
# 0             Angus Sampson  Leigh Whannell
# ...

# %%
new_df18.isnull().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      9
# actor_3_name     26
# genres            3
# movie_title       0
# dtype: int64

# %%
new_df18['actor_2_name']=new_df18['actor_2_name'].replace(np.NaN, 'unknown')
new_df18['actor_3_name']=new_df18['actor_3_name'].replace(np.NaN, 'unknown')
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           3
# movie_title      0
# dtype: int64

# %%
new_df18['comb'] = new_df18['actor_1_name'] +" "+ new_df18['actor_2_name']+" "+new_df18['actor_3_name']+" "+new_df18['director_name']+" "+new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name     actor_1_name  \
# 0                                         Adam Robitel        Lin Shaye
# 1                                     Lauren Wolkstein    Alex Pettyfer
# 2                                           Simon West   Dominic Cooper
# 3                                     Warwick Thornton      Bryan Brown
# 4                                   Jaume Collet-Serra      Liam Neeson
# ..                                                 ...              ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...     Will Ferrell
# 263  Adam McKay (director/screenplay); Christian Ba...   Christian Bale
# 264                                         Mimi Leder   Felicity Jones
# 265                                       Karyn Kusama    Nicole Kidman
# 266                                        David Slade  Fionn Whitehead
#
#                actor_2_name    actor_3_name  \
# 0             Angus Sampson  Leigh Whannell
# ...

# %% [markdown]
# # 2019 movies

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4, ignore_index=True), ignore_index=True), ignore_index=True)
df
# Out:
#       Opening  Opening.1             Title  \
# 0     JANUARY          4       Escape Room
# 1     JANUARY          4        Rust Creek
# 2     JANUARY          4  American Hangman
# 3     JANUARY         11  A Dog's Way Home
# 4     JANUARY         11        The Upside
# ..        ...        ...               ...
# 237  DECEMBER         25      Little Women
# 238  DECEMBER         25              1917
# 239  DECEMBER         25        Just Mercy
# 240  DECEMBER         27          Clemency
# 241  DECEMBER         27        Apparition
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
df['genres'] = df['Title'].map(lambda x: g_genre(str(x)))
df
# Out:
#       Opening  Opening.1             Title  \
# 0     JANUARY          4       Escape Room
# 1     JANUARY          4        Rust Creek
# 2     JANUARY          4  American Hangman
# 3     JANUARY         11  A Dog's Way Home
# 4     JANUARY         11        The Upside
# ..        ...        ...               ...
# 237  DECEMBER         25      Little Women
# 238  DECEMBER         25              1917
# 239  DECEMBER         25        Just Mercy
# 240  DECEMBER         27          Clemency
# 241  DECEMBER         27        Apparition
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 237      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 238              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 239        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 240          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 241        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres
# ...

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: g_director(str(x)))
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: g_actor1(x))
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: g_actor2(x))
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: g_actor3(x))
# Out:
# <ipython-input-39-d1e54e08d4fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: g_director(str(x)))
# <ipython-input-39-d1e54e08d4fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: g_actor1(x))
# <ipython-input-39-d1e54e08d4fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 237      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 238              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 239        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 240          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 241        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres  \
# ...

# %%
df_2019=df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name', 'actor_1_name','actor_2_name', 'actor_3_name', 'genres', 'movie_title']]

# %%
new_df19.isnull().sum()
new_df19['actor_2_name']=new_df19['actor_2_name'].replace(np.NaN, 'unknown')
new_df19['actor_3_name']=new_df19['actor_3_name'].replace(np.NaN, 'unknown')
new_df19['movie_title'] = new_df19['movie_title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] +" "+ new_df19['actor_2_name']+" "+new_df19['actor_3_name']+" "+new_df19['director_name']+" "+new_df19['genres']

# %%
new_df19
# Out:
#                                          director_name         actor_1_name  \
# 0                                         Adam Robitel       Taylor Russell
# 1                                          Jen McGowan    Hermione Corfield
# 2    Wilson Coneybeare (director/screenplay); Donal...    Donald Sutherland
# 3                                 Charles Martin Smith  Bryce Dallas Howard
# 4                                          Neil Burger       Bryan Cranston
# ..                                                 ...                  ...
# 237  Greta Gerwig (director/screenplay); Saoirse Ro...        Saoirse Ronan
# 238  Sam Mendes (director/screenplay); Krysty Wilso...        George MacKay
# 239  Destin Daniel Cretton (director/screenplay), A...    Michael B. Jordan
# 240  Chinonye Chukwu (director/screenplay); Alfre W...        Alfre Woodard
# 241  Waymon Boone (director/screenplay); Mena Suvar...          Mena Suvari
#
#              actor_2_name      actor_3_name  \
# ...

# %%
my_df = new_df18.append(new_df19, ignore_index=True)
my_df
# Out:
#                                          director_name       actor_1_name  \
# 0                                         Adam Robitel          Lin Shaye
# 1                                     Lauren Wolkstein      Alex Pettyfer
# 2                                           Simon West     Dominic Cooper
# 3                                     Warwick Thornton        Bryan Brown
# 4                                   Jaume Collet-Serra        Liam Neeson
# ..                                                 ...                ...
# 504  Greta Gerwig (director/screenplay); Saoirse Ro...      Saoirse Ronan
# 505  Sam Mendes (director/screenplay); Krysty Wilso...      George MacKay
# 506  Destin Daniel Cretton (director/screenplay), A...  Michael B. Jordan
# 507  Chinonye Chukwu (director/screenplay); Alfre W...      Alfre Woodard
# 508  Waymon Boone (director/screenplay); Mena Suvar...        Mena Suvari
#
#                actor_2_name    actor_3_name                   genres  \
# ...

# %%
old_df=pd.read_csv('datasets/new_data.csv')
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df, ignore_index=True)
final_df
# Out:
#                                           director_name       actor_1_name  \
# 0                                         James Cameron        CCH Pounder
# 1                                        Gore Verbinski        Johnny Depp
# 2                                            Sam Mendes    Christoph Waltz
# 3                                     Christopher Nolan          Tom Hardy
# 4                                           Doug Walker        Doug Walker
# ...                                                 ...                ...
# 5868  Greta Gerwig (director/screenplay); Saoirse Ro...      Saoirse Ronan
# 5869  Sam Mendes (director/screenplay); Krysty Wilso...      George MacKay
# 5870  Destin Daniel Cretton (director/screenplay), A...  Michael B. Jordan
# 5871  Chinonye Chukwu (director/screenplay); Alfre W...      Alfre Woodard
# 5872  Waymon Boone (director/screenplay); Mena Suvar...        Mena Suvari
#
#               actor_2_name          actor_3_name  \
# ...

# %%
final_df.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           4
# movie_title      0
# comb             4
# dtype: int64

# %%
final_df = final_df.dropna(how='any')
final_df.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('datasets/final_data.csv', index=False)
